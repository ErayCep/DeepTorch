# %%
import numpy as np
import matplotlib.pyplot as plt
matplotlib_inline.backend_inline.set_matplotlib_formats('svg')
import matplotlib_inline
import sympy as sym

# %%
def fx(x):
    return (np.cos(2*np.pi * x) + x**2)

def deriv(x):
    return -2*(np.pi*np.sin(2*math.pi*x) - x)

# %%
x = np.linspace(-2,2,2001)

plt.plot(x, fx(x), x, deriv(x))
plt.xlim(x[[0,-1]])
plt.grid()
plt.xlabel('x')
plt.ylabel('f(x')
plt.legend(['y', 'dy'])
plt.show()

# %%
localmin = np.random.choice(x, 1)

learning_rate = 0.01
train_count = 100

for i in range(train_count):
    a = deriv(localmin)
    localmin = localmin - a * learning_rate
localmin
# Out:
# array([-1.42506741])

# %%
plt.plot(x, fx(x), x, deriv(x))
plt.plot(localmin, deriv(localmin), 'ro')
plt.plot(localmin, fx(localmin), 'ro')

plt.xlim(x[[0,-1]])
plt.grid()
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend(['y', 'dy'])
plt.show()

# %%
localmin = np.random.choice(x, 1)

learning_rate = .01
train_count = 100

modelparams = np.zeros((train_count, 2))
for i in range(train_count):
    grad = deriv(localmin)    
    localmin = localmin - grad * learning_rate
    modelparams[i, :] = localmin, grad

localmin
# Out:
# /var/folders/85/j2qtn7190hzcnyrjdrk1grc80000gn/T/ipykernel_46584/249225821.py:10: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   modelparams[i, :] = localmin, grad
# array([0.47580245])

# %%
fig, ax = plt.subplots(1, 2, figsize=(12,4))

for i in range(2):
    ax[i].plot(modelparams[:, i], 'o-')
    ax[i].set_xlabel('Iteration')
    ax[i].set_title(f'Final estimated minimun: {localmin[0]:.5f}')

ax[0].set_ylabel('Local Minimum')
ax[1].set_ylabel('Derivative')
plt.show()

# %%
modelparams
# Out:
# array([[8.52890473e-01, 5.31095269e+00],
#        [7.85679702e-01, 6.72107710e+00],
#        [7.08706544e-01, 7.69731580e+00],
#        [6.33803537e-01, 7.49030074e+00],
#        [5.74310294e-01, 5.94932432e+00],
#        [5.34541898e-01, 3.97683953e+00],
#        [5.10321269e-01, 2.42206297e+00],
#        [4.96043025e-01, 1.42782434e+00],
#        [4.87684155e-01, 8.35887038e-01],
#        [4.82787721e-01, 4.89643328e-01],
#        [4.79913864e-01, 2.87385745e-01],
#        [4.78224242e-01, 1.68962214e-01],
#        [4.77229685e-01, 9.94556831e-02],
#        [4.76643815e-01, 5.85869594e-02],
#        [4.76298531e-01, 3.45284503e-02],
#        [4.76094978e-01, 2.03552861e-02],
#        [4.75974959e-01, 1.20019437e-02],
#        [4.75904185e-01, 7.07734126e-03],
#        [4.75862449e-01, 4.17363896e-03],
#        [4.75837835e-01, 2.46135984e-03],
#        [4.75823319e-01, 1.45159177e-03],
#        [4.75814758e-01, 8.56089732e-04],
#        [4.75809710e-01, 5.04890580e-04],
# ...
