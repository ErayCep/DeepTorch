# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
n1 = 50 #samples in dataset1
n2 = 50 #samples in dataset2
mu1 = 1 #population mean in dataset1
mu2 = 1.4 #population mean in dataset2

data1 = mu1 + np.random.randn(n1)
data2 = mu2 + np.random.randn(n2)

plt.plot(np.zeros(n1), data1, 'ro', markersize=14, markerfacecolor='w')
plt.plot(np.ones(n2), data2, 'bs', markersize=14, markerfacecolor='w')
plt.xlim([-1,2])
plt.xticks([0,1], labels=['Group 1', 'Group 2'])
plt.show()

# %%
t,p = stats.ttest_ind(data1, data2)
print(t)
print(p)
# Out:
# -1.3525409107722637
# 0.17931494870704057

# %%
fig = plt.figure(figsize=(10,4))

plt.plot(0 + np.random.randn(n1)/15, data1, 'ro', markerfacecolor='w', markersize=14)
plt.plot(1 + np.random.randn(n2)/15, data2, 'bs', markerfacecolor='w', markersize=14)
plt.xlim([-1,2])
plt.xticks([0,1], labels=['Group 1', 'Group 2'])
plt.show()
